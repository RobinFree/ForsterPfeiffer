# %%
import pandas as pd

# Einlesen der Tabelle
df = pd.read_csv('koordinaten_pfeiffer1.csv')

print(df.head)
# Out:
# <bound method NDFrame.head of          Column 1   Latitude   Longitude
# 0          Vienna  48.208333   16.372500
# 1          Brazil -14.000000  -53.000000
# 2           Chile -33.000000  -71.000000
# 3          Tahiti -17.666667 -149.466667
# 4           China  35.000000  105.000000
# ..            ...        ...         ...
# 78         Brazil -14.000000  -53.000000
# 79       Portugal  38.700000   -9.183333
# 80          Spain  40.200000   -3.500000
# 81          Italy  42.500000   12.500000
# 82  United States  39.828175  -98.579500
#
# [83 rows x 3 columns]>

# %%
import pandas as pd

# Einlesen der Tabelle
df2 = pd.read_csv('koordinaten_forster.csv')

print(df2.head)
# Out:
# <bound method NDFrame.head of                         Column 1  breitengrad  längengrad
# 0     Place Name unique manually          NaN         NaN
# 1               Ethiopian Empire    12.600000   37.466667
# 2                       Adihalli    13.294444   76.338889
# 3               Admiralitäts-Bay          NaN         NaN
# 4                  Adventure-Bay          NaN         NaN
# ...                          ...          ...         ...
# 1474                      Warioi    -1.647875  135.771035
# 1475                      Warioi    -1.647875  135.771035
# 1476                      Warioi    -1.647875  135.771035
# 1477                      Warioi    -1.647875  135.771035
# 1478                      Warioi    -1.647875  135.771035
#
# [1479 rows x 3 columns]>

# %%
import folium
#Tabelle Pfeiffer1
# Eine Tabelle nur mit den relevanten Informationen für die Visualisierung
df = df.rename(columns={'Column 1': 'place_name'})

# Entferne Zeilen mit fehlenden Koordinaten
df = df.dropna(subset=['Latitude', 'Longitude'])

# die Koordinaten sollten als Zahlenwerte vorliegen, wir stellen das hier nochmal sicher
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

#Tabelle Forster
df2 = pd.read_csv('koordinaten_forster.csv').rename(columns={
    'Column 1': 'place_name',
    'längengrad': 'Longitude',
    'breitengrad': 'Latitude'
})

df2 = df2.dropna(subset=['Latitude', 'Longitude'])
df2['Latitude'] = df2['Latitude'].astype(float)
df2['Longitude'] = df2['Longitude'].astype(float)


# Initialisieren der Karte mit Einstellungen, wo anfangs der Ausschnitt liegen soll
m = folium.Map(location=[51.0, 10.0], zoom_start=4)

for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['place_name'],
        tooltip=row['place_name'],
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(m)
for _, row in df2.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['place_name'],
        tooltip=row['place_name'],
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc62e9fd88b322db9e013e9bbc2048ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc62e9fd88b322db9e013e9bbc2048ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc62e9fd88b322db9e013e9bbc2048ba = L.map(
#                 &quot;map_dc62e9fd88b322db9e013e9bbc2048ba&quot;,
#                 {
#                     center: [51.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a519a12da23ad1df2018b18630e0b8d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a519a12da23ad1df2018b18630e0b8d6.addTo(map_dc62e9fd88b322db9e013e9bbc2048ba);
#
#
#             var marker_9dda6bad7455a995a816f7058097e816 = L.marker(
#                 [48.208333333333336, 16.3725],
#                 {
# }
#             ).addTo(map_dc62e9fd88b322db9e013e9bbc2048ba);
#
#
#             var icon_315cd71412d7f578ca1a4af3ec2ae56c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5e08fadcfb141564ed7e85ec0e56df84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4337944c75c69d33f1250e9dd41aa92e = $(`&lt;div id=&quot;html_4337944c75c69d33f1250e9dd41aa92e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vienna&lt;/div&gt;`)[0];
#                 popup_5e08fadcfb141564ed7e85ec0e56df84.setContent(html_4337944c75c69d33f1250e9dd41aa92e);
#
#
#
#         marker_9dda6bad7455a995a816f7058097e816.bindPopup(popup_5e08fadcfb141564ed7e85ec0e56df84)
#         ;
#
#
#
#
#             marker_9dda6bad7455a995a816f7058097e816.bindTooltip(
#                 `&lt;div&gt;
#                      Vienna
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9dda6bad7455a995a816f7058097e816.setIcon(icon_315cd71412d7f578ca1a4af3ec2ae56c);
#
#
#             var marker_d38b0a18fe06568d0d473826e48aa54f = L.marker(
#                 [-14.0, -53.0],
#                 {
# }
#             ).addTo(map_dc62e9fd88b322db9e013e9bbc2048ba);
#
#
#             var icon_de9b12fd2cf3e6fa97ee1d05688fce59 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_62bb5326c045945b6757cfc8daf88839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6d3f5c588a49aeeaed6c85507026ec7 = $(`&lt;div id=&quot;html_e6d3f5c588a49aeeaed6c85507026ec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brazil&lt;/div&gt;`)[0];
#                 popup_62bb5326c045945b6757cfc8daf88839.setContent(html_e6d3f5c588a49aeeaed6c85507026ec7);
#
#
#
#         marker_d38b0a18fe06568d0d473826e48aa54f.bindPopup(popup_62bb5326c045945b6757cfc8daf88839)
#         ;
#
#
#
#
#             marker_d38b0a18fe06568d0d473826e48aa54f.bindTooltip(
#                 `&lt;div&gt;
#                      Brazil
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d38b0a18fe06568d0d473826e48aa54f.setIcon(icon_de9b12fd2cf3e6fa97ee1d05688fce59);
#
#
#             var marker_272c9338f638e220650e43b6e51c27f7 = L.marker(
#                 [-33.0, -71.0],
#                 {
# }
#             ).addTo(map_dc62e9fd88b322db9e013e9bbc2048ba);
#
#
#             var icon_c8ff12ed1dc9b086c8b2a47aa9e611c2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_60c5c48a4c5af746f97ce265bd1b6de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e85e8ecfaab0d4db4264abe5f5991742 = $(`&lt;div id=&quot;html_e85e8ecfaab0d4db4264abe5f5991742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chile&lt;/div&gt;`)[0];
#                 popup_60c5c48a4c5af746f97ce265bd1b6de5.setContent(html_e85e8ecfaab0d4db4264abe5f5991742);
#
#
#
#         marker_272c9338f638e220650e43b6e51c27f7.bindPopup(popup_60c5c48a4c5af746f97ce265bd1b6de5)
#         ;
